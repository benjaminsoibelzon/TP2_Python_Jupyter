# %%
text = """Beautiful is better than ugly.
Explicit is better than implicit.
Simple is better than complex.
Complex is better than complicated.
Flat is better than nested.
Sparse is better than dense.
Readability counts.
Special cases aren't special enough to break the rules.
Although practicality beats purity.
Errors should never pass silently.
Unless explicitly silenced.
In the face of ambiguity, refuse the temptation to guess.
There should be one-- and preferably only one --obvious way
to do it.
Although that way may not be obvious at first unless you're
Dutch.
Now is better than never.
Although never is often better than *right* now.
If the implementation is hard to explain, it's a bad idea.
If the implementation is easy to explain, it may be a good
idea.
Namespaces are one honking great idea -- let's do more of
those!"""

# %%
import sys
import os

# Obtener la ruta del proyecto (carpeta TP2_Python_Jupyter)
project_root = os.path.dirname(os.getcwd())

# Ruta a la carpeta src
src_path = os.path.join(project_root, "src")

# Agregar src al path
if src_path not in sys.path:
    sys.path.append(src_path)

from funciones import analizar_texto

# Llamar a la función
total_lineas, total_palabras, promedio, lineas_sobre_promedio = analizar_texto(text)

print(f"Total de líneas: {total_lineas}")
print(f"Total de palabras: {total_palabras}")
print(f"Promedio de palabras por línea: {promedio:.2f}")
print(f"Líneas por encima del promedio ({promedio:.2f} palabras):")

for linea, cant in lineas_sobre_promedio:
    print(f" - {linea} ({cant} palabras)")
# Out:
# Total de líneas: 23
# Total de palabras: 137
# Promedio de palabras por línea: 5.96
# Líneas por encima del promedio (5.96 palabras):
#  - Special cases aren't special enough to break the rules. (9 palabras)
#  - In the face of ambiguity, refuse the temptation to guess. (10 palabras)
#  - There should be one-- and preferably only one --obvious way (10 palabras)
#  - Although that way may not be obvious at first unless you're (11 palabras)
#  - Although never is often better than *right* now. (8 palabras)
#  - If the implementation is hard to explain, it's a bad idea. (11 palabras)
#  - If the implementation is easy to explain, it may be a good (12 palabras)
#  - Namespaces are one honking great idea -- let's do more of (11 palabras)

# %%
playlist = [
    {"title": "Bohemian Rhapsody", "duration": "5:55"},
    {"title": "Hotel California", "duration": "6:30"},
    {"title": "Stairway to Heaven", "duration": "8:02"},
    {"title": "Imagine", "duration": "3:07"},
    {"title": "Smells Like Teen Spirit", "duration": "5:01"},
    {"title": "Billie Jean", "duration": "4:54"},
    {"title": "Hey Jude", "duration": "7:11"},
    {"title": "Like a Rolling Stone", "duration": "6:13"},
]

# %%
import sys, os
project_root = os.path.dirname(os.getcwd())
src_path = os.path.join(project_root, "src")
if src_path not in sys.path:
    sys.path.append(src_path)

# %%
from funciones import analizar_playlist

# %%
total_min, total_seg, larga, corta = analizar_playlist(playlist)

print(f"Duración total: {total_min}m {total_seg}s")
print(f'Canción más larga: "{larga["title"]}" ({larga["duration"]})')
print(f'Canción más corta: "{corta["title"]}" ({corta["duration"]})')
# Out:
# Duración total: 46m 53s
# Canción más larga: "Stairway to Heaven" (8:02)
# Canción más corta: "Imagine" (3:07)

# %%
import sys
sys.path.append("..\\src")

from funciones import filtrar_spoilers

# %%
review = """La película sigue a un grupo de astronautas que
viajan a Marte
en una misión de rescate. El capitán Torres lidera al equipo
a través
de tormentas solares y fallos en el sistema de navegación. Al
llegar
a Marte descubren que la base está abandonada y los
suministros
destruidos. Torres decide sacrificar la nave nodriza para
salvar
al equipo y logran volver a la Tierra en una cápsula de
emergencia.
El final revela que Torres sobrevivió gracias a un pasaje
secreto."""

# %%
entrada = input("Ingrese las palabras spoiler (separadas por coma): ")
spoilers = entrada.split(",")

print(filtrar_spoilers(review, spoilers))
# Out:
# La película sigue a un grupo de astronautas que
# viajan a *****
# en una misión de rescate. El capitán ****** lidera al equipo
# a través
# de tormentas solares y fallos en el sistema de navegación. Al
# llegar
# a ***** descubren que la base está abandonada y los
# suministros
# destruidos. ****** decide sacrificar la nave nodriza para
# salvar
# al equipo y logran volver a la Tierra en una cápsula de
# emergencia.
# El final revela que ****** sobrevivió gracias a un pasaje
# secreto.

# %%
import sys
sys.path.append("..\\src")

from funciones import filtrar_spoilers, validar_email

# %%
email = input("Ingrese un email: ")

if validar_email(email):
    print("El email es válido.")
else:
    print("El email no es válido.")
# Out:
# El email es válido.

# %%
import sys
sys.path.append("..\\src")

# %%
from funciones import filtrar_spoilers, validar_email, calcular_envio

# %%
peso = float(input("Ingrese el peso del paquete (kg): "))
zona = input("Ingrese la zona de destino (local/regional/nacional): ")

costo = calcular_envio(peso, zona)

if costo is None:
    print("Zona no válida. Las zonas disponibles son: local, regional, nacional.")
else:
    print(f"Costo de envío: ${costo}")
# Out:
# Zona no válida. Las zonas disponibles son: local, regional, nacional.
